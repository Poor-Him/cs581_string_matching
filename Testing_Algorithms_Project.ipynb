# %%
import tempfile, os

base = "/content/drive/MyDrive/2026 Algorithms Project"
texts_dir = f"{base}/Texts"

# Load patterns
'''with open(f"{base}/patterns/dna_pattern_1.txt") as f:
    dna_pat_1 = "\\n".join(line.strip() for line in f.read().splitlines())
with open(f"{base}/patterns/dna_pattern_2.txt") as f:
    dna_pat_2 = "\\n".join(line.strip() for line in f.read().splitlines())'''
with open(f"{base}/patterns/dna_pattern_1.txt") as f:
    dna_pat_1 = f.read().strip().replace("\n", "")
with open(f"{base}/patterns/dna_pattern_2.txt") as f:
    dna_pat_2 = f.read().strip().replace("\n", "")
with open(f"{base}/patterns/text_pattern_1.txt") as f:
    text_pat_1 = "\\n".join(line.strip() for line in f.read().splitlines())
with open(f"{base}/patterns/text_pattern_2.txt") as f:
    text_pat_2 = "\\n".join(line.strip() for line in f.read().splitlines())

script = f"{base}/Programs/knuth-morris-pratt.py"

def run_script(script, filename, pattern, repeat=20, ignore_case=False):
    with tempfile.NamedTemporaryFile(mode='w', suffix='.txt', delete=False, encoding='utf-8') as f:
        f.write(pattern)
        tmp = f.name
    try:
        flags = "--ignore-case" if ignore_case else ""
        # !python "{script}" --input-file "{filename}" --pattern-file "{tmp}" --repeat {repeat} {flags}
    finally:
        os.unlink(tmp)
if("DFA" in script):
    for filename in os.listdir(texts_dir):
        full_path = os.path.join(texts_dir, filename)
        if filename.endswith(".fna"):
            for pat in [dna_pat_1, dna_pat_2]:
                run_script(script, full_path, pat, ignore_case=True)
                print("")
        elif filename.endswith(".txt"):
            for pat in [text_pat_1, text_pat_2]:
                run_script(script, full_path, pat)
                print("")
else:
    for filename in os.listdir(texts_dir):
        if filename.endswith(".fna"):
            for pat in [dna_pat_1, dna_pat_2]:
                run_script(script, filename, pat, ignore_case=True)
                print("")
        elif filename.endswith(".txt"):
            for pat in [text_pat_1, text_pat_2]:
                run_script(script, filename, pat)
                print("")
# Out:
# Input file:         DNASmall.fna
# Detected type:      fasta
# Pattern length (m): 5
# Input length (n):   48556462
# Alphabet size:      5
# Preprocessing time: 0.00000145 s
# Matching time:      8.48098830 s
# Total time:         8.48098976 s
# Average time:       7.39446951 s
# Match count:        33496
#
# Input file:         DNASmall.fna
# Detected type:      fasta
# Pattern length (m): 4000
# Input length (n):   48556462
# Alphabet size:      5
# Preprocessing time: 0.00051610 s
# Matching time:      6.25159512 s
# Total time:         6.25211121 s
# Average time:       6.97261491 s
# Match count:        0
#
# Input file:         jtw.txt
# Detected type:      text
# Pattern length (m): 5
# Input length (n):   4018714
# Alphabet size:      4
# Preprocessing time: 0.00000175 s
# Matching time:      0.41883195 s
# Total time:         0.41883370 s
# Average time:       0.51484724 s
# Match count:        1
#
# Input file:         jtw.txt
# Detected type:      text
# Pattern length (m): 5452
# Input length (n):   4018714
# Alphabet size:      56
# Preprocessing time: 0.00058543 s
# Matching time:      0.40186064 s
# Total time:         0.40244607 s
# Average time:       0.52158402 s
# Match count:        0
#
# Input file:         Harry_Potter_all_books_preprocessed.txt
# Detected type:      text
# Pattern length (m): 5
# Input length (n):   5991294
# Alphabet size:      4
# Preprocessing time: 0.00000173 s
# Matching time:      0.62223170 s
# Total time:         0.62223343 s
# Average time:       0.74695328 s
# Match count:        33
#
# Input file:         Harry_Potter_all_books_preprocessed.txt
# Detected type:      text
# Pattern length (m): 5452
# Input length (n):   5991294
# Alphabet size:      56
# Preprocessing time: 0.00057411 s
# Matching time:      0.59656965 s
# Total time:         0.59714375 s
# Average time:       0.71043820 s
# Match count:        0
#
# Input file:         rotp.txt
# Detected type:      text
# Pattern length (m): 5
# Input length (n):   2426922
# Alphabet size:      4
# Preprocessing time: 0.00000124 s
# Matching time:      0.25443482 s
# Total time:         0.25443606 s
# Average time:       0.25529692 s
# Match count:        0
#
# Input file:         rotp.txt
# Detected type:      text
# Pattern length (m): 5452
# Input length (n):   2426922
# Alphabet size:      56
# Preprocessing time: 0.00057581 s
# Matching time:      0.25675672 s
# Total time:         0.25733254 s
# Average time:       0.35465892 s
# Match count:        0
#
# Input file:         text1.txt
# Detected type:      text
# Pattern length (m): 5
# Input length (n):   39
# Alphabet size:      4
# Preprocessing time: 0.00000061 s
# Matching time:      0.00000371 s
# Total time:         0.00000432 s
# Average time:       0.00000715 s
# Match count:        0
#
# Input file:         text1.txt
# Detected type:      text
# Pattern length (m): 5452
# Input length (n):   39
# Alphabet size:      56
# Preprocessing time: 0.00057535 s
# Matching time:      0.00000640 s
# Total time:         0.00058176 s
# Average time:       0.00061408 s
# Match count:        0
#
# Input file:         newsarticle.txt
# Detected type:      text
# Pattern length (m): 5
# Input length (n):   7602
# Alphabet size:      4
# Preprocessing time: 0.00000068 s
# Matching time:      0.00077037 s
# Total time:         0.00077105 s
# Average time:       0.00081952 s
# Match count:        0
#
# Input file:         newsarticle.txt
# Detected type:      text
# Pattern length (m): 5452
# Input length (n):   7602
# Alphabet size:      56
# Preprocessing time: 0.00057177 s
# Matching time:      0.00072597 s
# Total time:         0.00129773 s
# Average time:       0.00134374 s
# Match count:        0
#
# Input file:         combined_text.txt
# Detected type:      text
# Pattern length (m): 5
# Input length (n):   15651504
# Alphabet size:      4
# Preprocessing time: 0.00000130 s
# Matching time:      1.94090323 s
# Total time:         1.94090453 s
# Average time:       1.91570144 s
# Match count:        34
#
# Input file:         combined_text.txt
# Detected type:      text
# Pattern length (m): 5452
# Input length (n):   15651504
# Alphabet size:      56
# Preprocessing time: 0.00058335 s
# Matching time:      1.58608060 s
# Total time:         1.58666395 s
# Average time:       1.90593588 s
# Match count:        1
#
# Input file:         DNAReallySmall.fna
# Detected type:      fasta
# Pattern length (m): 5
# Input length (n):   29903
# Alphabet size:      5
# Preprocessing time: 0.00000113 s
# Matching time:      0.00373052 s
# Total time:         0.00373164 s
# Average time:       0.00373228 s
# Match count:        8
#
# Input file:         DNAReallySmall.fna
# Detected type:      fasta
# Pattern length (m): 4000
# Input length (n):   29903
# Alphabet size:      5
# Preprocessing time: 0.00052204 s
# Matching time:      0.00408671 s
# Total time:         0.00460875 s
# Average time:       0.00509963 s
# Match count:        0
